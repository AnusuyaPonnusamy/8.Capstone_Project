# %%
import pickle

# %% [raw]
# print("Please enter the input values in the following order:")
# print("1. discounted_price")
# print("2. discount_percentage")
# print("3. rating")
# print("4. rating_count")
#
# print("\nExample:")
# print("[499, 40, 4.3, 5000]")

# %%
import warnings

warnings.filterwarnings(
    "ignore",
    message="X does not have valid feature names"
)

# %%
loaded_model=pickle.load(open("finalized_model_SVM_linear.sav",'rb'))
result=loaded_model.predict([[499,40,4.3,5000]])
result
# Out:
# array(['CONSIDER'], dtype=object)

# %%
result=loaded_model.predict([[100,50,4.9,15000]])
result
# Out:
# array(['BUY'], dtype=object)

# %%
result=loaded_model.predict([[1000,10,4,500]])
result
# Out:
# array(["DON'T BUY"], dtype=object)
